# %%
import requests
import pandas as pd
import io
import os
from datetime import datetime, timedelta
from typing import Optional, List

# --- Configuration ---
API_KEYS = [
    "API_KEY_HERE_1",
    "API_KEY_HERE_2",
]

LOCATION = "New York, NY, United States"  # Specific for Visual Crossing
OVERALL_START_DATETIME_STR = "2019-01-01T00:00:00"
# We go a bit into the future to cover the full dataset range
OVERALL_END_DATETIME_STR = "2025-10-01T00:00:00"

CHUNK_SIZE_HOURS = 930  # 15 Days per chunk (Safe for API limits)
OUTPUT_FILENAME = "nyc_weather_hourly_2019_2025.csv"
BACKUP_FILENAME = "nyc_weather_hourly_2019_2025.csv.bak"

# The "High Impact" Features only
ELEMENTS_HOURLY = [
    "datetime",
    "temp",
    "feelslike",
    "precip",
    "snow",
    "snowdepth",
    "windspeed",
    "visibility",
    "conditions",
    "icon",
]

# %%
def fetch_hourly_weather_data(
    api_key: str,
    location: str,
    start_datetime_str: str,
    end_datetime_str: str,
    elements: Optional[List[str]] = None,
) -> Optional[pd.DataFrame]:
    BASE_URL = "https://weather.visualcrossing.com/VisualCrossingWebServices/rest/services/timeline/"
    # Note: Visual Crossing uses dates in URL, so we format them cleanly
    request_url = f"{BASE_URL}{location}/{start_datetime_str}/{end_datetime_str}"

    params = {
        "unitGroup": "metric",  # CRITICAL: Ensures Celsius, KM, MM
        "include": "hours",
        "key": api_key,
        "contentType": "csv",
    }

    if elements:
        params["elements"] = ",".join(elements)

    try:
        response = requests.get(request_url, params=params)
        response.raise_for_status()
        return pd.read_csv(io.StringIO(response.text))
    except requests.exceptions.HTTPError as http_err:
        print(f"    -> HTTP Error: {http_err.response.status_code} with Key ending in ...{api_key[-4:]}")
        return None
    except Exception as err:
        print(f"    -> Unexpected error: {err}")
        return None


def clean_and_deduplicate(filename):
    """
    Post-processing to remove overlaps and sort.
    """
    print("\n🧹 Starting Post-Download Cleanup...")
    if not os.path.exists(filename):
        print("❌ File not found.")
        return

    df = pd.read_csv(filename)
    original_count = len(df)

    # 1. Deduplicate based on datetime
    df = df.drop_duplicates(subset=["datetime"], keep="first")

    # 2. Sort
    df["datetime"] = pd.to_datetime(df["datetime"])
    df = df.sort_values("datetime")

    # 3. Fill Nulls for Snow/Precip (Visual Crossing sometimes leaves 0 as Null)
    cols_to_fix = ["snow", "snowdepth", "precip"]
    for col in cols_to_fix:
        if col in df.columns:
            df[col] = df[col].fillna(0)

    removed = original_count - len(df)
    print(f"✅ Cleanup Complete. Removed {removed} duplicate rows.")
    print(f"📅 Data Range: {df['datetime'].min()} to {df['datetime'].max()}")

    # Save back
    df.to_csv(filename, index=False)
    print(f"💾 Saved cleaned data to {filename}")

# %%
# 1. Resume Logic
if os.path.exists(OUTPUT_FILENAME):
    print("📂 Existing data file found. Resuming...")
    # We read the last few lines to find the last date
    df_existing = pd.read_csv(OUTPUT_FILENAME)
    last_datetime_str = df_existing["datetime"].iloc[-1]
    try:
        last_dt_obj = datetime.strptime(last_datetime_str, "%Y-%m-%dT%H:%M:%S")
    except ValueError:
        # Handle cases where seconds might be missing or format varies
        last_dt_obj = datetime.fromisoformat(last_datetime_str)

    current_start_dt = last_dt_obj + timedelta(hours=1)
    print(f"⏭️ Resuming from: {current_start_dt}")
else:
    print("🆕 Starting new download.")
    current_start_dt = datetime.strptime(OVERALL_START_DATETIME_STR, "%Y-%m-%dT%H:%M:%S")

final_end_dt = datetime.strptime(OVERALL_END_DATETIME_STR, "%Y-%m-%dT%H:%M:%S")

print("=" * 60)

key_index = 0

while current_start_dt < final_end_dt:
    if key_index >= len(API_KEYS):
        print("❌ All API keys exhausted for this session.")
        break

    current_key = API_KEYS[key_index]

    # Calculate chunk end
    chunk_end_dt = current_start_dt + timedelta(hours=CHUNK_SIZE_HOURS)
    if chunk_end_dt > final_end_dt:
        chunk_end_dt = final_end_dt

    start_str = current_start_dt.strftime("%Y-%m-%dT%H:%M:%S")
    end_str = chunk_end_dt.strftime("%Y-%m-%dT%H:%M:%S")

    print(f"📥 Fetching: {start_str} -> {end_str} (Key #{key_index + 1})")

    df_chunk = fetch_hourly_weather_data(
        api_key=current_key,
        location=LOCATION,
        start_datetime_str=start_str,
        end_datetime_str=end_str,
        elements=ELEMENTS_HOURLY,
    )

    if df_chunk is not None and not df_chunk.empty:
        # Atomic Append
        header = not os.path.exists(OUTPUT_FILENAME)
        df_chunk.to_csv(OUTPUT_FILENAME, mode="a", header=header, index=False)
        print(f"   ✅ Saved {len(df_chunk)} rows.")

        # Advance time
        current_start_dt = chunk_end_dt + timedelta(hours=1)
    else:
        print("   ⚠️ Chunk failed or Key limit reached. Switching key...")
        key_index += 1

print("=" * 60)
# Run Cleanup
clean_and_deduplicate(OUTPUT_FILENAME)
# Out:
# 🆕 Starting new download.
# ============================================================
# 📥 Fetching: 2019-01-01T00:00:00 -> 2019-02-08T18:00:00 (Key #1)
#    ✅ Saved 936 rows.
# 📥 Fetching: 2019-02-08T19:00:00 -> 2019-03-19T13:00:00 (Key #1)
#     -> HTTP Error: 429 with Key ending in ...62YZ
#    ⚠️ Chunk failed or Key limit reached. Switching key...
# 📥 Fetching: 2019-02-08T19:00:00 -> 2019-03-19T13:00:00 (Key #2)
#    ✅ Saved 959 rows.
# 📥 Fetching: 2019-03-19T14:00:00 -> 2019-04-27T08:00:00 (Key #2)
#     -> HTTP Error: 429 with Key ending in ...75V8
#    ⚠️ Chunk failed or Key limit reached. Switching key...
# 📥 Fetching: 2019-03-19T14:00:00 -> 2019-04-27T08:00:00 (Key #3)
#    ✅ Saved 960 rows.
# 📥 Fetching: 2019-04-27T09:00:00 -> 2019-06-05T03:00:00 (Key #3)
#     -> HTTP Error: 429 with Key ending in ...T6V6
#    ⚠️ Chunk failed or Key limit reached. Switching key...
# 📥 Fetching: 2019-04-27T09:00:00 -> 2019-06-05T03:00:00 (Key #4)
#    ✅ Saved 960 rows.
# 📥 Fetching: 2019-06-05T04:00:00 -> 2019-07-13T22:00:00 (Key #4)
#     -> HTTP Error: 429 with Key ending in ...3JS5
#    ⚠️ Chunk failed or Key limit reached. Switching key...
# 📥 Fetching: 2019-06-05T04:00:00 -> 2019-07-13T22:00:00 (Key #5)
#    ✅ Saved 936 rows.
# 📥 Fetching: 2019-07-13T23:00:00 -> 2019-08-21T17:00:00 (Key #5)
#     -> HTTP Error: 429 with Key ending in ...7J6N
#    ⚠️ Chunk failed or Key limit reached. Switching key...
# 📥 Fetching: 2019-07-13T23:00:00 -> 2019-08-21T17:00:00 (Key #6)
#    ✅ Saved 960 rows.
# 📥 Fetching: 2019-08-21T18:00:00 -> 2019-09-29T12:00:00 (Key #6)
#     -> HTTP Error: 429 with Key ending in ...6FS9
#    ⚠️ Chunk failed or Key limit reached. Switching key...
# 📥 Fetching: 2019-08-21T18:00:00 -> 2019-09-29T12:00:00 (Key #7)
#    ✅ Saved 960 rows.
# 📥 Fetching: 2019-09-29T13:00:00 -> 2019-11-07T07:00:00 (Key #7)
#     -> HTTP Error: 429 with Key ending in ...D5QL
#    ⚠️ Chunk failed or Key limit reached. Switching key...
# 📥 Fetching: 2019-09-29T13:00:00 -> 2019-11-07T07:00:00 (Key #8)
#    ✅ Saved 961 rows.
# 📥 Fetching: 2019-11-07T08:00:00 -> 2019-12-16T02:00:00 (Key #8)
#     -> HTTP Error: 429 with Key ending in ...8GBT
#    ⚠️ Chunk failed or Key limit reached. Switching key...
# 📥 Fetching: 2019-11-07T08:00:00 -> 2019-12-16T02:00:00 (Key #9)
#    ✅ Saved 960 rows.
# 📥 Fetching: 2019-12-16T03:00:00 -> 2020-01-23T21:00:00 (Key #9)
#     -> HTTP Error: 429 with Key ending in ...2UUT
#    ⚠️ Chunk failed or Key limit reached. Switching key...
# 📥 Fetching: 2019-12-16T03:00:00 -> 2020-01-23T21:00:00 (Key #10)
#     -> HTTP Error: 401 with Key ending in ...79W2
#    ⚠️ Chunk failed or Key limit reached. Switching key...
# 📥 Fetching: 2019-12-16T03:00:00 -> 2020-01-23T21:00:00 (Key #11)
#    ✅ Saved 936 rows.
# 📥 Fetching: 2020-01-23T22:00:00 -> 2020-03-02T16:00:00 (Key #11)
#     -> HTTP Error: 429 with Key ending in ...3XWX
#    ⚠️ Chunk failed or Key limit reached. Switching key...
# 📥 Fetching: 2020-01-23T22:00:00 -> 2020-03-02T16:00:00 (Key #12)
#    ✅ Saved 960 rows.
# 📥 Fetching: 2020-03-02T17:00:00 -> 2020-04-10T11:00:00 (Key #12)
#     -> HTTP Error: 429 with Key ending in ...UN9H
#    ⚠️ Chunk failed or Key limit reached. Switching key...
# 📥 Fetching: 2020-03-02T17:00:00 -> 2020-04-10T11:00:00 (Key #13)
#    ✅ Saved 959 rows.
# 📥 Fetching: 2020-04-10T12:00:00 -> 2020-05-19T06:00:00 (Key #13)
#     -> HTTP Error: 429 with Key ending in ...ZY28
#    ⚠️ Chunk failed or Key limit reached. Switching key...
# 📥 Fetching: 2020-04-10T12:00:00 -> 2020-05-19T06:00:00 (Key #14)
#    ✅ Saved 960 rows.
# 📥 Fetching: 2020-05-19T07:00:00 -> 2020-06-27T01:00:00 (Key #14)
#     -> HTTP Error: 429 with Key ending in ...YEXL
#    ⚠️ Chunk failed or Key limit reached. Switching key...
# 📥 Fetching: 2020-05-19T07:00:00 -> 2020-06-27T01:00:00 (Key #15)
#    ✅ Saved 960 rows.
# 📥 Fetching: 2020-06-27T02:00:00 -> 2020-08-04T20:00:00 (Key #15)
#     -> HTTP Error: 429 with Key ending in ...7D5A
#    ⚠️ Chunk failed or Key limit reached. Switching key...
# 📥 Fetching: 2020-06-27T02:00:00 -> 2020-08-04T20:00:00 (Key #16)
#    ✅ Saved 936 rows.
# 📥 Fetching: 2020-08-04T21:00:00 -> 2020-09-12T15:00:00 (Key #16)
#     -> HTTP Error: 429 with Key ending in ...WFCC
#    ⚠️ Chunk failed or Key limit reached. Switching key...
# 📥 Fetching: 2020-08-04T21:00:00 -> 2020-09-12T15:00:00 (Key #17)
#    ✅ Saved 960 rows.
# 📥 Fetching: 2020-09-12T16:00:00 -> 2020-10-21T10:00:00 (Key #17)
#     -> HTTP Error: 429 with Key ending in ...WM5B
#    ⚠️ Chunk failed or Key limit reached. Switching key...
# 📥 Fetching: 2020-09-12T16:00:00 -> 2020-10-21T10:00:00 (Key #18)
#    ✅ Saved 960 rows.
# 📥 Fetching: 2020-10-21T11:00:00 -> 2020-11-29T05:00:00 (Key #18)
#     -> HTTP Error: 429 with Key ending in ...PPQL
#    ⚠️ Chunk failed or Key limit reached. Switching key...
# 📥 Fetching: 2020-10-21T11:00:00 -> 2020-11-29T05:00:00 (Key #19)
#    ✅ Saved 961 rows.
# 📥 Fetching: 2020-11-29T06:00:00 -> 2021-01-07T00:00:00 (Key #19)
#     -> HTTP Error: 429 with Key ending in ...NNVP
#    ⚠️ Chunk failed or Key limit reached. Switching key...
# 📥 Fetching: 2020-11-29T06:00:00 -> 2021-01-07T00:00:00 (Key #20)
#    ✅ Saved 960 rows.
# 📥 Fetching: 2021-01-07T01:00:00 -> 2021-02-14T19:00:00 (Key #20)
#     -> HTTP Error: 429 with Key ending in ...SSAV
#    ⚠️ Chunk failed or Key limit reached. Switching key...
# 📥 Fetching: 2021-01-07T01:00:00 -> 2021-02-14T19:00:00 (Key #21)
#    ✅ Saved 936 rows.
# 📥 Fetching: 2021-02-14T20:00:00 -> 2021-03-25T14:00:00 (Key #21)
#     -> HTTP Error: 429 with Key ending in ...D3EB
#    ⚠️ Chunk failed or Key limit reached. Switching key...
# 📥 Fetching: 2021-02-14T20:00:00 -> 2021-03-25T14:00:00 (Key #22)
#    ✅ Saved 959 rows.
# 📥 Fetching: 2021-03-25T15:00:00 -> 2021-05-03T09:00:00 (Key #22)
#     -> HTTP Error: 429 with Key ending in ...YRBH
#    ⚠️ Chunk failed or Key limit reached. Switching key...
# 📥 Fetching: 2021-03-25T15:00:00 -> 2021-05-03T09:00:00 (Key #23)
#    ✅ Saved 960 rows.
# 📥 Fetching: 2021-05-03T10:00:00 -> 2021-06-11T04:00:00 (Key #23)
#     -> HTTP Error: 429 with Key ending in ...PF5C
#    ⚠️ Chunk failed or Key limit reached. Switching key...
# 📥 Fetching: 2021-05-03T10:00:00 -> 2021-06-11T04:00:00 (Key #24)
#    ✅ Saved 960 rows.
# 📥 Fetching: 2021-06-11T05:00:00 -> 2021-07-19T23:00:00 (Key #24)
#     -> HTTP Error: 429 with Key ending in ...9XE6
#    ⚠️ Chunk failed or Key limit reached. Switching key...
# 📥 Fetching: 2021-06-11T05:00:00 -> 2021-07-19T23:00:00 (Key #25)
#    ✅ Saved 936 rows.
# 📥 Fetching: 2021-07-20T00:00:00 -> 2021-08-27T18:00:00 (Key #25)
#     -> HTTP Error: 429 with Key ending in ...XG7S
#    ⚠️ Chunk failed or Key limit reached. Switching key...
# 📥 Fetching: 2021-07-20T00:00:00 -> 2021-08-27T18:00:00 (Key #26)
#    ✅ Saved 936 rows.
# 📥 Fetching: 2021-08-27T19:00:00 -> 2021-10-05T13:00:00 (Key #26)
#     -> HTTP Error: 429 with Key ending in ...WBLZ
#    ⚠️ Chunk failed or Key limit reached. Switching key...
# 📥 Fetching: 2021-08-27T19:00:00 -> 2021-10-05T13:00:00 (Key #27)
#    ✅ Saved 960 rows.
# 📥 Fetching: 2021-10-05T14:00:00 -> 2021-11-13T08:00:00 (Key #27)
#     -> HTTP Error: 429 with Key ending in ...8U8R
#    ⚠️ Chunk failed or Key limit reached. Switching key...
# 📥 Fetching: 2021-10-05T14:00:00 -> 2021-11-13T08:00:00 (Key #28)
#    ✅ Saved 961 rows.
# 📥 Fetching: 2021-11-13T09:00:00 -> 2021-12-22T03:00:00 (Key #28)
#     -> HTTP Error: 429 with Key ending in ...H5KP
#    ⚠️ Chunk failed or Key limit reached. Switching key...
# 📥 Fetching: 2021-11-13T09:00:00 -> 2021-12-22T03:00:00 (Key #29)
#    ✅ Saved 960 rows.
# 📥 Fetching: 2021-12-22T04:00:00 -> 2022-01-29T22:00:00 (Key #29)
#     -> HTTP Error: 429 with Key ending in ...M49C
#    ⚠️ Chunk failed or Key limit reached. Switching key...
# 📥 Fetching: 2021-12-22T04:00:00 -> 2022-01-29T22:00:00 (Key #30)
#    ✅ Saved 936 rows.
# 📥 Fetching: 2022-01-29T23:00:00 -> 2022-03-09T17:00:00 (Key #30)
#     -> HTTP Error: 429 with Key ending in ...JS52
#    ⚠️ Chunk failed or Key limit reached. Switching key...
# 📥 Fetching: 2022-01-29T23:00:00 -> 2022-03-09T17:00:00 (Key #31)
#    ✅ Saved 960 rows.
# 📥 Fetching: 2022-03-09T18:00:00 -> 2022-04-17T12:00:00 (Key #31)
#     -> HTTP Error: 429 with Key ending in ...HUTE
#    ⚠️ Chunk failed or Key limit reached. Switching key...
# 📥 Fetching: 2022-03-09T18:00:00 -> 2022-04-17T12:00:00 (Key #32)
#    ✅ Saved 959 rows.
# 📥 Fetching: 2022-04-17T13:00:00 -> 2022-05-26T07:00:00 (Key #32)
#     -> HTTP Error: 429 with Key ending in ...CGNH
#    ⚠️ Chunk failed or Key limit reached. Switching key...
# 📥 Fetching: 2022-04-17T13:00:00 -> 2022-05-26T07:00:00 (Key #33)
#    ✅ Saved 960 rows.
# 📥 Fetching: 2022-05-26T08:00:00 -> 2022-07-04T02:00:00 (Key #33)
#     -> HTTP Error: 429 with Key ending in ...QEJ8
#    ⚠️ Chunk failed or Key limit reached. Switching key...
# 📥 Fetching: 2022-05-26T08:00:00 -> 2022-07-04T02:00:00 (Key #34)
#    ✅ Saved 960 rows.
# 📥 Fetching: 2022-07-04T03:00:00 -> 2022-08-11T21:00:00 (Key #34)
#     -> HTTP Error: 429 with Key ending in ...VBRM
#    ⚠️ Chunk failed or Key limit reached. Switching key...
# 📥 Fetching: 2022-07-04T03:00:00 -> 2022-08-11T21:00:00 (Key #35)
#    ✅ Saved 936 rows.
# 📥 Fetching: 2022-08-11T22:00:00 -> 2022-09-19T16:00:00 (Key #35)
#     -> HTTP Error: 429 with Key ending in ...9EM2
#    ⚠️ Chunk failed or Key limit reached. Switching key...
# 📥 Fetching: 2022-08-11T22:00:00 -> 2022-09-19T16:00:00 (Key #36)
#    ✅ Saved 960 rows.
# 📥 Fetching: 2022-09-19T17:00:00 -> 2022-10-28T11:00:00 (Key #36)
#     -> HTTP Error: 429 with Key ending in ...QTQU
#    ⚠️ Chunk failed or Key limit reached. Switching key...
# 📥 Fetching: 2022-09-19T17:00:00 -> 2022-10-28T11:00:00 (Key #37)
#    ✅ Saved 960 rows.
# 📥 Fetching: 2022-10-28T12:00:00 -> 2022-12-06T06:00:00 (Key #37)
#     -> HTTP Error: 429 with Key ending in ...QHFT
#    ⚠️ Chunk failed or Key limit reached. Switching key...
# 📥 Fetching: 2022-10-28T12:00:00 -> 2022-12-06T06:00:00 (Key #38)
#    ✅ Saved 961 rows.
# 📥 Fetching: 2022-12-06T07:00:00 -> 2023-01-14T01:00:00 (Key #38)
#     -> HTTP Error: 429 with Key ending in ...TLFK
#    ⚠️ Chunk failed or Key limit reached. Switching key...
# 📥 Fetching: 2022-12-06T07:00:00 -> 2023-01-14T01:00:00 (Key #39)
#    ✅ Saved 960 rows.
# 📥 Fetching: 2023-01-14T02:00:00 -> 2023-02-21T20:00:00 (Key #39)
#     -> HTTP Error: 429 with Key ending in ...NU2Y
#    ⚠️ Chunk failed or Key limit reached. Switching key...
# 📥 Fetching: 2023-01-14T02:00:00 -> 2023-02-21T20:00:00 (Key #40)
#    ✅ Saved 936 rows.
# 📥 Fetching: 2023-02-21T21:00:00 -> 2023-04-01T15:00:00 (Key #40)
#     -> HTTP Error: 429 with Key ending in ...DRFG
#    ⚠️ Chunk failed or Key limit reached. Switching key...
# 📥 Fetching: 2023-02-21T21:00:00 -> 2023-04-01T15:00:00 (Key #41)
#    ✅ Saved 959 rows.
# 📥 Fetching: 2023-04-01T16:00:00 -> 2023-05-10T10:00:00 (Key #41)
#     -> HTTP Error: 429 with Key ending in ...6PJX
#    ⚠️ Chunk failed or Key limit reached. Switching key...
# 📥 Fetching: 2023-04-01T16:00:00 -> 2023-05-10T10:00:00 (Key #42)
#    ✅ Saved 960 rows.
# 📥 Fetching: 2023-05-10T11:00:00 -> 2023-06-18T05:00:00 (Key #42)
#     -> HTTP Error: 429 with Key ending in ...TQSR
#    ⚠️ Chunk failed or Key limit reached. Switching key...
# 📥 Fetching: 2023-05-10T11:00:00 -> 2023-06-18T05:00:00 (Key #43)
#    ✅ Saved 960 rows.
# 📥 Fetching: 2023-06-18T06:00:00 -> 2023-07-27T00:00:00 (Key #43)
#     -> HTTP Error: 429 with Key ending in ...TLX4
#    ⚠️ Chunk failed or Key limit reached. Switching key...
# 📥 Fetching: 2023-06-18T06:00:00 -> 2023-07-27T00:00:00 (Key #44)
#    ✅ Saved 960 rows.
# 📥 Fetching: 2023-07-27T01:00:00 -> 2023-09-03T19:00:00 (Key #44)
#     -> HTTP Error: 429 with Key ending in ...AFMZ
#    ⚠️ Chunk failed or Key limit reached. Switching key...
# 📥 Fetching: 2023-07-27T01:00:00 -> 2023-09-03T19:00:00 (Key #45)
#    ✅ Saved 936 rows.
# 📥 Fetching: 2023-09-03T20:00:00 -> 2023-10-12T14:00:00 (Key #45)
#     -> HTTP Error: 429 with Key ending in ...W2SU
#    ⚠️ Chunk failed or Key limit reached. Switching key...
# 📥 Fetching: 2023-09-03T20:00:00 -> 2023-10-12T14:00:00 (Key #46)
#    ✅ Saved 960 rows.
# 📥 Fetching: 2023-10-12T15:00:00 -> 2023-11-20T09:00:00 (Key #46)
#     -> HTTP Error: 429 with Key ending in ...9PA2
#    ⚠️ Chunk failed or Key limit reached. Switching key...
# 📥 Fetching: 2023-10-12T15:00:00 -> 2023-11-20T09:00:00 (Key #47)
#    ✅ Saved 961 rows.
# 📥 Fetching: 2023-11-20T10:00:00 -> 2023-12-29T04:00:00 (Key #47)
#     -> HTTP Error: 429 with Key ending in ...7277
#    ⚠️ Chunk failed or Key limit reached. Switching key...
# 📥 Fetching: 2023-11-20T10:00:00 -> 2023-12-29T04:00:00 (Key #48)
#     -> HTTP Error: 401 with Key ending in ...ZNQV
#    ⚠️ Chunk failed or Key limit reached. Switching key...
# 📥 Fetching: 2023-11-20T10:00:00 -> 2023-12-29T04:00:00 (Key #49)
#    ✅ Saved 960 rows.
# 📥 Fetching: 2023-12-29T05:00:00 -> 2024-02-05T23:00:00 (Key #49)
#     -> HTTP Error: 429 with Key ending in ...KB84
#    ⚠️ Chunk failed or Key limit reached. Switching key...
# 📥 Fetching: 2023-12-29T05:00:00 -> 2024-02-05T23:00:00 (Key #50)
#    ✅ Saved 936 rows.
# 📥 Fetching: 2024-02-06T00:00:00 -> 2024-03-15T18:00:00 (Key #50)
#     -> HTTP Error: 429 with Key ending in ...M799
#    ⚠️ Chunk failed or Key limit reached. Switching key...
# 📥 Fetching: 2024-02-06T00:00:00 -> 2024-03-15T18:00:00 (Key #51)
#    ✅ Saved 935 rows.
# 📥 Fetching: 2024-03-15T19:00:00 -> 2024-04-23T13:00:00 (Key #51)
#     -> HTTP Error: 429 with Key ending in ...L4UL
#    ⚠️ Chunk failed or Key limit reached. Switching key...
# 📥 Fetching: 2024-03-15T19:00:00 -> 2024-04-23T13:00:00 (Key #52)
#    ✅ Saved 960 rows.
# 📥 Fetching: 2024-04-23T14:00:00 -> 2024-06-01T08:00:00 (Key #52)
#     -> HTTP Error: 429 with Key ending in ...GLF4
#    ⚠️ Chunk failed or Key limit reached. Switching key...
# 📥 Fetching: 2024-04-23T14:00:00 -> 2024-06-01T08:00:00 (Key #53)
#    ✅ Saved 960 rows.
# 📥 Fetching: 2024-06-01T09:00:00 -> 2024-07-10T03:00:00 (Key #53)
#     -> HTTP Error: 429 with Key ending in ...Q9J3
#    ⚠️ Chunk failed or Key limit reached. Switching key...
# 📥 Fetching: 2024-06-01T09:00:00 -> 2024-07-10T03:00:00 (Key #54)
#    ✅ Saved 960 rows.
# 📥 Fetching: 2024-07-10T04:00:00 -> 2024-08-17T22:00:00 (Key #54)
#     -> HTTP Error: 429 with Key ending in ...3UEP
#    ⚠️ Chunk failed or Key limit reached. Switching key...
# 📥 Fetching: 2024-07-10T04:00:00 -> 2024-08-17T22:00:00 (Key #55)
#    ✅ Saved 936 rows.
# 📥 Fetching: 2024-08-17T23:00:00 -> 2024-09-25T17:00:00 (Key #55)
#     -> HTTP Error: 429 with Key ending in ...VX9Q
#    ⚠️ Chunk failed or Key limit reached. Switching key...
# 📥 Fetching: 2024-08-17T23:00:00 -> 2024-09-25T17:00:00 (Key #56)
#    ✅ Saved 960 rows.
# 📥 Fetching: 2024-09-25T18:00:00 -> 2024-11-03T12:00:00 (Key #56)
#     -> HTTP Error: 429 with Key ending in ...8HK2
#    ⚠️ Chunk failed or Key limit reached. Switching key...
# 📥 Fetching: 2024-09-25T18:00:00 -> 2024-11-03T12:00:00 (Key #57)
#    ✅ Saved 961 rows.
# 📥 Fetching: 2024-11-03T13:00:00 -> 2024-12-12T07:00:00 (Key #57)
#     -> HTTP Error: 429 with Key ending in ...2R78
#    ⚠️ Chunk failed or Key limit reached. Switching key...
# 📥 Fetching: 2024-11-03T13:00:00 -> 2024-12-12T07:00:00 (Key #58)
#    ✅ Saved 961 rows.
# 📥 Fetching: 2024-12-12T08:00:00 -> 2025-01-20T02:00:00 (Key #58)
#     -> HTTP Error: 429 with Key ending in ...VA2A
#    ⚠️ Chunk failed or Key limit reached. Switching key...
# 📥 Fetching: 2024-12-12T08:00:00 -> 2025-01-20T02:00:00 (Key #59)
#    ✅ Saved 960 rows.
# 📥 Fetching: 2025-01-20T03:00:00 -> 2025-02-27T21:00:00 (Key #59)
#     -> HTTP Error: 429 with Key ending in ...3W7L
#    ⚠️ Chunk failed or Key limit reached. Switching key...
# 📥 Fetching: 2025-01-20T03:00:00 -> 2025-02-27T21:00:00 (Key #60)
#    ✅ Saved 936 rows.
# 📥 Fetching: 2025-02-27T22:00:00 -> 2025-04-07T16:00:00 (Key #60)
#     -> HTTP Error: 429 with Key ending in ...MC5G
#    ⚠️ Chunk failed or Key limit reached. Switching key...
# 📥 Fetching: 2025-02-27T22:00:00 -> 2025-04-07T16:00:00 (Key #61)
#    ✅ Saved 959 rows.
# 📥 Fetching: 2025-04-07T17:00:00 -> 2025-05-16T11:00:00 (Key #61)
#     -> HTTP Error: 429 with Key ending in ...JN79
#    ⚠️ Chunk failed or Key limit reached. Switching key...
# 📥 Fetching: 2025-04-07T17:00:00 -> 2025-05-16T11:00:00 (Key #62)
#    ✅ Saved 960 rows.
# 📥 Fetching: 2025-05-16T12:00:00 -> 2025-06-24T06:00:00 (Key #62)
#     -> HTTP Error: 429 with Key ending in ...HE69
#    ⚠️ Chunk failed or Key limit reached. Switching key...
# 📥 Fetching: 2025-05-16T12:00:00 -> 2025-06-24T06:00:00 (Key #63)
#    ✅ Saved 960 rows.
# 📥 Fetching: 2025-06-24T07:00:00 -> 2025-08-02T01:00:00 (Key #63)
#     -> HTTP Error: 429 with Key ending in ...LCWA
#    ⚠️ Chunk failed or Key limit reached. Switching key...
# 📥 Fetching: 2025-06-24T07:00:00 -> 2025-08-02T01:00:00 (Key #64)
#    ✅ Saved 960 rows.
# 📥 Fetching: 2025-08-02T02:00:00 -> 2025-09-09T20:00:00 (Key #64)
#     -> HTTP Error: 429 with Key ending in ...6KYL
#    ⚠️ Chunk failed or Key limit reached. Switching key...
# 📥 Fetching: 2025-08-02T02:00:00 -> 2025-09-09T20:00:00 (Key #65)
#    ✅ Saved 936 rows.
# 📥 Fetching: 2025-09-09T21:00:00 -> 2025-10-01T00:00:00 (Key #65)
#     -> HTTP Error: 429 with Key ending in ...YSN6
#    ⚠️ Chunk failed or Key limit reached. Switching key...
# 📥 Fetching: 2025-09-09T21:00:00 -> 2025-10-01T00:00:00 (Key #66)
#    ✅ Saved 552 rows.
# ============================================================
#
# 🧹 Starting Post-Download Cleanup...
# ✅ Cleanup Complete. Removed 1471 duplicate rows.
# 📅 Data Range: 2019-01-01 00:00:00 to 2025-10-01 23:00:00
# 💾 Saved cleaned data to nyc_weather_hourly_2019_2025.csv
